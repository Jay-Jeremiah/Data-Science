# %%
# the ipynb extension is for the using python in jupyter notebook
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('Agg')

# %%
de = pd.read_csv('C:\\Users\\Jeremiah\\Documents\\DataScience\\Data-Science\\Ploting\\data17.csv')
print(de.to_string())
# Out:
#    Duration  Average_Pulse  Max_Pulse  Calorie_Burnage  Hours_Work  Hours_Sleep
# 0        30             80        120              240          10            7
# 1        45             85        120              250          10            7
# 2        45             90        130              260           8            7
# 3        60             95        130              270           8            7
# 4        60            100        140              280           0            7
# 5        60            105        140              290           7            8
# 6        60            110        145              300           7            8
# 7        45            115        145              310           8            8
# 8        60            120        150              320           0            8
# 9        45            125        150              330           8            8

# %%
de.plot(x='Average_Pulse', y='Calorie_Burnage', kind='line')
plt.ylabel('Calorie_Burnage')
plt.ylim(ymin=0)
plt.xlim(xmin=0)
plt.show()
